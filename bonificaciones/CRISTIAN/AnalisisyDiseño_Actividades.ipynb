# %% [markdown]
# <a href="https://colab.research.google.com/github/Psychohistorian11/BitBusters/blob/master/bonificaciones/CRISTIAN/AnalisisyDise%C3%B1o_Actividades.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def leng(string, aux = 0):
    if len(string) == 0:
        return aux
    else:
        aux = aux + 1
        return leng(string[1:],aux)

print(leng("Andres"))
# Out:
# 6

# %%
def InvertString(string, aux = ""):
    if len(string) == 0:
        return aux
    else:
        aux = aux + string[-1]
        return InvertString(string[:-1], aux)


print(InvertString("Hola"))
# Out:
# nóicadnuf al a oidulerP

# %%
def bubble_sort(arr): # 0(n*n)
    n = len(arr) #0(1)
    for i in range(n): #0(n)
        for j in range(0, n-i-1): #(n*n)
            if arr[j] > arr[j+1]: #(n*n)
                arr[j], arr[j+1] = arr[j+1], arr[j] #(n*n)

# Ejemplo de uso:
lista = [64, 34, 25, 12, 22, 11, 90] # 0(1)
bubble_sort(lista) # 0(n*n)
print("Lista ordenada:", lista) #0(1)

#Ecuación = 2 0(1) + 2 0(n*n)
